# %%
import cv2
import matplotlib.pyplot as plt
import imutils

# %%
ddepth = cv2.CV_16S
kernel_size = 3
window_name = "Laplace Demo"

# %%
image = cv2.imread("imgs/CM002/CM002F8.JPG")[1300:2400, 2100:3200]

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(image_gray)

# %%
image_gray_blur = cv2.GaussianBlur(gray, (3, 3), 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4d0a0b16a633> in <module>
# ----> 1 image_gray_blur = cv2.GaussianBlur(gray, (3, 3), 0)
#
# NameError: name 'gray' is not defined

# %%
plt.imshow(image_gray_blur)

# %%
image_gray_blur_laplace = cv2.Laplacian(image_gray_blur, 1, ksize=11)

# %%
plt.imshow(image_gray_blur_laplace)

# %%
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
edged = cv2.Canny(blurred, 30, 150)
plt.imshow(edged)

# %%
cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
c = max(cnts, key=cv2.contourArea)
# draw the largest contour on the image
cv2.drawContours(image, [c], -1, (0, 255, 0), 2)

# %%
plt.imshow(image)

# %%
plt.imshow(edged)
