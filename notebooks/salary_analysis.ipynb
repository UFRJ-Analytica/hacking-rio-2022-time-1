# %% [markdown]
# ## Etapa de Análise

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# - Dados utilizados

# %%
ds_salaries = pd.read_csv('../backend/data/ds_salaries.csv', index_col=0)
ds_salaries.head()

# %% [markdown]
# ## Insights e Gráficos Interessantes
#
# Este ambiente pode ser usado para gerar insights e simular ideias de gráficos que serão reproduzidos no frontend.
#
# É recomendado verificar se existe um gráfico correspondente no [plotly.js](https://plotly.com/javascript)

# %% [markdown]
# ### Variação de Salários ao longo dos anos
#
# Gráfico: [lineplot](https://plotly.com/javascript/line-charts/)

# %%
ds_salaries['work_year'] = ds_salaries['work_year'].astype('str')

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=ds_salaries, x="work_year", y="salary", hue="company_size")
# Out:
# <AxesSubplot:xlabel='work_year', ylabel='salary'>
